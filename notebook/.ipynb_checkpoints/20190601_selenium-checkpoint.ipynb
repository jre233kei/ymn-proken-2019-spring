# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 2.9MB/s ta 0:00:011
# Requirement already satisfied: urllib3 in /Users/fukuikota/miniconda3/lib/python3.6/site-packages (from selenium) (1.22)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install chromedriver-binary
# Out:
# Collecting chromedriver-binary
#   Downloading https://files.pythonhosted.org/packages/97/79/dff51c0fd1eb6dea04762f6353581680b157e78de6ed866a08ee1c7773d0/chromedriver-binary-75.0.3770.8.0.tar.gz
# Building wheels for collected packages: chromedriver-binary
#   Running setup.py bdist_wheel for chromedriver-binary ... done
#   Stored in directory: /Users/fukuikota/Library/Caches/pip/wheels/30/27/2f/53691e12e1f4a1409f8893d76ea42ec737691a87ded39bbd66
# Successfully built chromedriver-binary
# Installing collected packages: chromedriver-binary
# Successfully installed chromedriver-binary-75.0.3770.8.0
# You are using pip version 18.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !brew install chromedriver
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# atlantis                   erlang@21                  pprint
# catch2                     heatshrink                 spice-gtk
# clzip                      include-what-you-use       spirv-tools
# csvq                       libzt                      terraform@0.11
# dbmate                     lizard
# deno                       molten-vk
# ==> Updated Formulae
# bison ✔                                  minio
# cmake ✔                                  minio-mc
# libevent ✔                               mkl-dnn
# libidn2 ✔                                mkvtoolnix
# libmagic ✔                               mlt
# msgpack ✔                                mmark
# perl ✔                                   mmseqs2
# vim ✔                                    mongo-c-driver
# wget ✔                                   mono-libgdiplus
# acpica                                   mpop
# aide                                     msktutil
# akka                                     mupdf-tools
# aliyun-cli                               mutt
# allure                                   n
# ammonite-repl                            nanopb-generator
# angular-cli                              nats-streaming-server
# ansible                                  nave
# ant@1.9                                  ncdc
# apache-archiva                           nco
# apache-drill                             needle
# arangodb                                 neo4j
# arpack                                   neovim
# artifactory                              netdata
# asdf                                     nginx
# aspectj                                  nifi-registry
# astrometry-net                           nlopt
# atari800                                 nnn
# auditbeat                                node
# augeas                                   node-build
# avra                                     node@10
# avro-c                                   node_exporter
# avro-cpp                                 nomad
# avro-tools                               notmuch
# aws-okta                                 numpy
# aws-sdk-cpp                              octave
# awscli                                   opa
# axel                                     opencascade
# b2-tools                                 opencoarrays
# babel                                    openshift-cli
# babl                                     openssl@1.1
# bat                                      openvdb
# bazel                                    operator-sdk
# bear                                     osc
# bedops                                   ospray
# bee                                      owfs
# binaryen                                 p11-kit
# bind                                     packer
# bit                                      paket
# bitrise                                  pandoc-crossref
# bowtie2                                  paperkey
# buku                                     parallel
# byteman                                  parallelstl
# bzt                                      passenger
# calicoctl                                pdfpc
# cargo-completion                         pdns
# cc65                                     peru
# ccextractor                              pgbadger
# ccls                                     pgcli
# certbot                                  pgformatter
# cfengine                                 phoronix-test-suite
# cfn-lint                                 php
# cglm                                     php-cs-fixer
# cgrep                                    php@7.2
# chakra                                   phpstan
# charm                                    phpunit
# checkstyle                               physfs
# circleci                                 picard-tools
# cmark-gfm                                picat
# cockroach                                pick
# cocoapods                                pilosa
# conan                                    pinfo
# conserver                                planck
# consul                                   plzip
# convox                                   pmd
# corsixth                                 pngquant
# cppad                                    postgresql@10
# cql                                      postgresql@9.4
# cracklib                                 postgresql@9.5
# crc32c                                   pre-commit
# cryptol                                  presto
# csound                                   proguard
# curl                                     proj
# curl-openssl                             prometheus
# cython                                   proteinortho
# dartsim                                  protoc-gen-go
# dav1d                                    pulumi
# dcd                                      pure-ftpd
# dcm2niix                                 pypy
# dep                                      pyside
# dhall                                    qalculate-gtk
# dhall-json                               qbs
# diffoscope                               qca
# digdag                                   qd
# dita-ot                                  qpdf
# django-completion                        qrupdate
# dmd                                      quantlib
# dnscontrol                               quazip
# dnstwist                                 quilt
# docfx                                    qwt
# docker-machine-driver-xhyve              rabbitmq
# doctl                                    radare2
# double-conversion                        rancid
# dscanner                                 range-v3
# dub                                      raylib
# dynare                                   rdesktop
# elasticsearch                            re2
# elasticsearch@5.6                        rebar3
# embree                                   recoverjpeg
# emscripten                               redis
# epubcheck                                redo
# erlang                                   remind
# etl                                      reposurgeon
# exploitdb                                restview
# eye-d3                                   rhino
# faas-cli                                 riemann
# faudio                                   riff
# ffsend                                   rom-tools
# file-formula                             roswell
# firebase-cli                             rt-audio
# flintrock                                rtmidi
# flow                                     rust
# fluxctl                                  rustup-init
# fn                                       s-search
# fobis                                    scalariform
# folly                                    scipy
# fonttools                                scmpuff
# fq                                       sdb
# freeradius-server                        sdcc
# frugal                                   sdl2_ttf
# fuseki                                   serd
# gandi.cli                                serf
# gecode                                   serverless
# genact                                   shc
# ghq                                      ship
# ghr                                      shogun
# git-cinnabar                             shyaml
# git-ftp                                  siril
# git-quick-stats                          sk
# git-review                               skaffold
# gitg                                     skopeo
# gitlab-runner                            sleuthkit
# gitless                                  smali
# glib                                     smimesign
# glooctl                                  sn0int
# glslang                                  solr
# gmic                                     source-to-image
# gnupg                                    sourcery
# gnuplot                                  sparse
# gnutls                                   spin
# gollum                                   spirv-cross
# google-authenticator-libpam              sqlmap
# google-benchmark                         sratom
# googler                                  srt
# gor                                      sshtrix
# goreleaser                               sslh
# grafana                                  sslscan
# grails                                   stellar-core
# grpc                                     step
# grpcurl                                  stk
# gtk-gnutella                             stout
# gx                                       strongswan
# h3                                       stunnel
# hana                                     subversion
# hapi-fhir-cli                            suite-sparse
# harfbuzz                                 sundials
# hebcal                                   superlu
# heimdal                                  supervisor
# hexyl                                    swi-prolog
# highlight                                swift-protobuf
# hlint                                    swiftformat
# homebank                                 swimat
# hugo                                     sync_gateway
# hypre                                    synfig
# ibex                                     sysbench
# imagemagick                              talloc
# imageoptim-cli                           tass64
# inlets                                   tbb
# ipfs                                     tcsh
# ispc                                     tdlib
# istioctl                                 telegraf
# ivykis                                   terraform
# jdnssec-tools                            terragrunt
# jena                                     terrahub
# jenkins                                  testssl
# jenkins-job-builder                      texmath
# jmxterm                                  tika
# joplin                                   tippecanoe
# jsonschema2pojo                          tkdiff
# juju                                     tmuxinator-completion
# just                                     tomcat
# khal                                     tomcat@7
# kibana                                   tomcat@8
# kitchen-sync                             tomee-plus
# kobalt                                   tomee-webprofile
# kops                                     topgrade
# ktlint                                   traefik
# kubecfg                                  trafficserver
# kubeprod                                 treefrog
# kubernetes-cli                           trezor-agent
# kubernetes-helm                          triton
# kubernetes-service-catalog-client        tundra
# lego                                     typescript
# lf                                       uncrustify
# libdazzle                                ungit
# libdc1394                                urdfdom_headers
# libimagequant                            velero
# libjwt                                   vert.x
# libphonenumber                           vim@7.4
# libpsl                                   vips
# libqalculate                             visp
# librealsense                             volt
# libressl                                 vulkan-headers
# librsvg                                  wabt
# libsodium                                wartremover
# libsoup                                  watchexec
# libuv                                    webpack
# lilv                                     websocat
# linkerd                                  websocketd
# llvm                                     weechat
# lmod                                     whois
# logstash                                 wine
# lsd                                      wiredtiger
# lv2                                      wireguard-go
# mame                                     wiremock-standalone
# mariadb                                  wireshark
# mariadb-connector-c                      wp-cli-completion
# mariadb@10.1                             wtf
# mariadb@10.2                             wxmaxima
# mat2                                     wxpython
# math-comp                                xctool
# maxwell                                  xmake
# mesa                                     xmrig
# mesos                                    xpdf
# metricbeat                               xplanet
# mgba                                     xsimd
# micronaut                                yle-dl
# micropython                              you-get
# mighttpd2                                youtube-dl
# mill                                     yq
# minimal-racket
# ==> Deleted Formulae
# compose2kube        gtk-engines         rlvm                whirr
# erlang@18           gtk-murrine-engine  tomcat@6            xmoto
# Error: No available formula with the name "chromedriver"
# It was migrated from homebrew/core to homebrew/cask.
# You can access it again by running:
#   brew tap homebrew/cask
# And then you can install it by running:
#   brew cask install chromedriver

# %%
import time
from selenium import webdriver

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://ikujipapa.net/archives/16621')
result = driver.find_elements_by_tag_name('p')
result_parents = set()
for r in result:
    result_parents.add(r.find_element_by_xpath('..'))

for r in result_parents:
    print(r.get_attribute("innerhtml"))
    
print([r.text for r in result])
time.sleep(5) # Let the user actually see something!
driver.quit()
